# %% [markdown]
# 1. Select all females from Florida. Expected columns in order:
#
# first_name as FirstName
# last_name as LastName
# salary as Salary
# gender as Gender
# state as State

# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("population.db")

df = pd.read_sql("SELECT * FROM population", con=conn)

Females_Florida = df[(df["state"] == "Florida") & (df["gender"]=='Female')]

Females_Florida
# Out:
#           id first_name  last_name                          email  gender  \
# 1          2        Mia  Tuddenham        mtuddenham1@addthis.com  Female
# 48        49      Doris    Wolfers          dwolfers1c@sbwire.com  Female
# 96        97     Louisa     Lummis          llummis2o@foxnews.com  Female
# 116      117     Cicily    Rhelton          crhelton38@flavors.me  Female
# 128      129    Kirstyn     Allbon               kallbon3k@un.org  Female
# ...      ...        ...        ...                            ...     ...
# 11543  11544    Ronnica     Hearle           rhearlef5@hao123.com  Female
# 11557  11558  Cassandra   Meriguet  cmeriguetfj@cocolog-nifty.com  Female
# 11566  11567    Camilla     Likely       clikelyfs@friendfeed.com  Female
# 11570  11571       Edin   Martinec           emartinecfw@admin.ch  Female
# 11626  11627    Melania    Laville       mlavillehg@canalblog.com  Female
#
#         salary    state
# 1       154398  Florida
# 48      278456  Florida
# ...

# %% [markdown]
# 2. Select all people whose email ends with @apache.org and find how many of those are male and female.

# %%
apache = df[df["email"].str.endswith("@apache.org")]

apache.head(5)
# Out:
#         id first_name    last_name                      email gender   salary  \
# 15      16   Bearnard       Bazire        bbaziref@apache.org   Male   541515
# 667    668     Vachel  Fareweather  vfareweatherij@apache.org   Male  1829717
# 1994  1995       Redd        Reeds        rreedsrm@apache.org   Male   761904
# 2141  2142    Shaughn     Petrussi     spetrussi3x@apache.org   Male  1683091
# 2486  2487    Norbert     Sharpley     nsharpleydi@apache.org   Male   293775
#
#            state
# 15      Michigan
# 667       Nevada
# 1994  California
# 2141  California
# 2486   Tennessee

# %%
genders = apache["gender"].value_counts().reset_index()

genders
# Out:
#    gender  count
# 0    Male     13
# 1  Female      8

# %% [markdown]
# 3. How many male people earn more than 1M?

# %%
salary_1m = df[(df["salary"]>1000000) & (df["gender"]=='Male')]

salary_1m.head()
# Out:
#     id first_name  last_name                           email gender   salary  \
# 13  14  Sebastien      Breem          sbreemd@technorati.com   Male  1133137
# 19  20        Pat     Dunbar                pdunbarj@irs.gov   Male  1424714
# 22  23    Gilburt     Metson            gmetsonm@cornell.edu   Male  1034660
# 24  25       Omar  Willshear       owillshearo@biglobe.ne.jp   Male  1727275
# 26  27    Raymund   Dodgshon  rdodgshonq@cargocollective.com   Male  1096837
#
#            state
# 13   Mississippi
# 19  Pennsylvania
# 22         Idaho
# 24        Kansas
# 26      Illinois

# %% [markdown]
# 4. Select all females from Alabama who have a salary below 800K. Show:
#
# first_name as FirstName
# last_name as LastName
# salary as Salary

# %%
Fem_alabama = df[(df["salary"]<800000) & (df["gender"] == 'Female') & (df["state"] == "Alabama")]

Fem_alabama = Fem_alabama.rename(columns={"first_name":"FirstName", "last_name":"LastName", "salary":"salary"})

Fem_alabama.head()
# Out:
#       id FirstName   LastName                       email  gender  salary  \
# 11    12   Ronalda  Southcott     rsouthcottb@nytimes.com  Female  589810
# 172  173      Ilka     Stucke      istucke4s@edublogs.org  Female  336655
# 326  327     Monah     Cayton  mcayton92@domainmarket.com  Female  376462
# 371  372     Helsa    Aartsen       haartsenab@weebly.com  Female  794142
# 730  731    Dannie   Riccardo      driccardoka@dyndns.org  Female   78730
#
#        state
# 11   Alabama
# 172  Alabama
# 326  Alabama
# 371  Alabama
# 730  Alabama

# %% [markdown]
# 5. How many people from Texas have an email ending with @hotmail.com?

# %%
Texas = df[df["state"]=="Texas"]
Texas = Texas[Texas["email"].str.endswith("@hotmail.com")]
Texas_people = Texas["id"].count()

print(Texas)
print(Texas_people)
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, email, gender, salary, state]
# Index: []
# 0

# %% [markdown]
# 6. Find all males earning between 400K and 900K in California.

# %%
california = df[(df["gender"]=='Male') & (df["salary"]<400000) & (df["salary"]<900000) & (df["state"]=="California")]
california.head()
# Out:
#       id first_name      last_name                             email gender  \
# 7      8       Jone         Pegden           jpegden7@washington.edu   Male
# 86    87     Emmott        Smeeton         esmeeton2e@guardian.co.uk   Male
# 264  265     Hamnet         Stobie              hstobie7c@ebay.co.uk   Male
# 283  284  Cleveland  McDermott-Row  cmcdermottrow7v@reverbnation.com   Male
# 399  400      Trace     FitzGeorge      tfitzgeorgeb3@altervista.org   Male
#
#      salary       state
# 7    327962  California
# 86   390998  California
# 264  390674  California
# 283   32715  California
# 399  386415  California

# %% [markdown]
# 7. Count the number of females from New York with a salary over 500K.

# %%
new_york = df[(df["salary"]>500000) & (df["state"]=='New York') & (df["gender"])=='Female']
new_york_people = new_york["id"].count()

print(new_york)
print(new_york_people)
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, email, gender, salary, state]
# Index: []
# 0

# %% [markdown]
# 8. List the top 10 highest-paid people from Georgia, showing:
#
# first_name as FirstName
# last_name as LastName
# salary as Salary

# %%
Georgia = df[df["state"]=="Georgia"]
Georgia_10 = df.nlargest(10, "salary")

Georgia_10 = Georgia_10.rename(columns= {"first_name": "FirstName", "last_name":"LastName", "salary":"Salary"})

Georgia_10
# Out:
#           id   FirstName  LastName                        email  gender  \
# 6081    6082      Sisile    Goward  sgoward29@timesonline.co.uk  Female
# 3911    3912       Pearl   Benoist          pbenoistpb@lulu.com  Female
# 6790    6791      Leeann    Fealty            lfealtyly@ask.com  Female
# 7635    7636     Susette    Emeney           semeneyhn@bing.com  Female
# 11018  11019       Corny    Berlin          cberlink@cdbaby.com    Male
# 7716    7717       Xylia   O'Leary          xolearyjw@house.gov  Female
# 10055  10056     Mariska     Cerie           mcerie1k@webmd.com  Female
# 7588    7589      Paulie  Vannuchi        pvannuchigc@webmd.com    Male
# 4974    4975  Claudianus    Dewire         cdewirer2@tripod.com    Male
# 8228    8229        Kipp    Myrick          kmyrick6c@wufoo.com    Male
#
#         Salary         state
# 6081   2000000  Pennsylvania
# 3911   1999968         Texas
# 6790   1999129      Colorado
# 7635   1999095       Georgia
# ...

# %% [markdown]
# 9. How many people have last names starting with S and earn more than 300K?

# %%
starting_s = df[df["last_name"].str.endswith("s")]

s_abv300 = df[df["salary"]>300000]

s_abv300.head()
# Out:
#    id first_name  last_name                          email  gender   salary  \
# 0   1      Armin    Coltart           acoltart0@abc.net.au    Male   368693
# 2   3   Kirsteni   Brafield         kbrafield2@arizona.edu  Female  1230304
# 3   4     Phylis    Furlong  pfurlong3@merriam-webster.com  Female  1567795
# 4   5     Wandis  Loveredge       wloveredge4@hatena.ne.jp  Female  1136950
# 5   6      Denis     Martyn               dmartyn5@unc.edu    Male   547205
#
#                   state
# 0  District of Columbia
# 2               Georgia
# 3            California
# 4               Alabama
# 5           Connecticut

# %% [markdown]
# 10. Find the average salary of all females in Oklahoma.

# %%
Oklahoma = df[(df["gender"]=='Female') & (df["state"]=="Oklahoma")]

oklahoma_avg = Oklahoma["salary"].mean()

print(oklahoma_avg)
# Out:
# 1020987.7195121951

# %% [markdown]
# 11. List all people from Florida whose emails end with .net.

# %%
Florida = df[df["state"]=="Florida"]
Florida_email = Florida[Florida["email"].str.endswith(".net")]

Florida_email.head()
# Out:
#         id first_name  last_name                        email  gender  \
# 327    328       Coop   Chaimson  cchaimson93@themeforest.net    Male
# 818    819       Jobi    Cutmere        jcutmeremq@cpanel.net  Female
# 924    925      Chris   Garfirth      cgarfirthpo@behance.net  Female
# 1101  1102      Waite  Rudderham      wrudderham2t@seesaa.net    Male
# 1242  1243         Em    Graffin     egraffin6q@clickbank.net  Female
#
#        salary    state
# 327    296781  Florida
# 818   1561427  Florida
# 924    416553  Florida
# 1101  1259094  Florida
# 1242   620022  Florida

# %% [markdown]
# 12. How many people with first names starting with K have a salary above 1M?

# %%
first_k = salary_1m[salary_1m["first_name"].str.startswith("K")]

first_k.head()
# Out:
#       id first_name last_name                     email gender   salary  \
# 164  165     Kurtis  Tucknutt          ktucknutt4k@g.co   Male  1792904
# 273  274     Kellby   Kimbrey    kkimbrey7l@t-online.de   Male  1382061
# 302  303       Kane   Downing   kdowning8e@slashdot.org   Male  1663579
# 343  344    Klemens  Jephcote        kjephcote9j@a8.net   Male  1227316
# 441  442    Killian   Jacquet  kjacquetc9@posterous.com   Male  1070042
#
#                     state
# 164            California
# 273            California
# 302  District of Columbia
# 343             Louisiana
# 441            California

# %% [markdown]
# 13. Select all people with gmail.com in their email and a salary below 200K.

# %%
salary_200k = df[df['salary']<200000]

gmail = salary_200k[salary_200k['email'].str.contains("gmail.com")]

gmail
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, email, gender, salary, state]
# Index: []

# %% [markdown]
# 14. Find the minimum salary for males from Ohio.

# %%
males = df[df["state"]=='Ohio']

min_salary = males["salary"].min()

min_salary
# Out:
# np.int64(19860)

# %% [markdown]
# 15. How many females from California have a salary above 800K?

# %%
california_females = df[(df["state"]=="California") & (df["salary"]>800000)]

counting_females = california_females['gender'].count()

counting_females
# Out:
# np.int64(797)

# %% [markdown]
# 16. List the last names and salaries of all males earning over 1.2M.

# %%
earning_12m = df[(df["gender"]=="Male")&(df["salary"]>1200000)]

earning_12m_names = earning_12m[["salary",'last_name']]

earning_12m_names.head()
# Out:
#      salary  last_name
# 19  1424714     Dunbar
# 24  1727275  Willshear
# 53  1213441      Chick
# 63  1752514     Persey
# 66  1337608    Redolfi

# %% [markdown]
# 17. Select all people with edu in their email and a salary above 1.5M.

# %%
salary_15m = df[df['salary']>1500000]

email_edu = salary_15m[salary_15m['email'].str.contains("edu")]

email_edu.head()
# Out:
#       id first_name  last_name                      email  gender   salary  \
# 10    11       Addi  Rucklesse      arucklessea@upenn.edu  Female  1811361
# 72    73   Granthem  Essberger  gessberger20@illinois.edu    Male  1587610
# 100  101        Gun     Cutler     gcutler2s@virginia.edu    Male  1673082
# 150  151     Caresa      Takis      ctakis46@illinois.edu  Female  1605712
# 235  236  Gaultiero     Duddle       gduddle6j@utexas.edu    Male  1989965
#
#           state
# 10     New York
# 72   New Jersey
# 100       Texas
# 150     Florida
# 235     Florida

# %% [markdown]
# 18. How many people live in Alabama and have a salary below 100K?

# %%
Alabama = df[(df["salary"]<100000) & (df["state"]=="Alabama")]

count_alabama_people = Alabama['id'].count()

count_alabama_people
# Out:
# np.int64(5)

# %% [markdown]
# 19. List all people with last names ending in n and salaries above 600K.

# %%
salary_600k = df[df["salary"]>600000]
ending_n = salary_600k[salary_600k["last_name"].str.endswith('n')]

ending_n.head()
# Out:
#     id first_name last_name                           email  gender   salary  \
# 22  23    Gilburt    Metson            gmetsonm@cornell.edu    Male  1034660
# 26  27    Raymund  Dodgshon  rdodgshonq@cargocollective.com    Male  1096837
# 42  43    Auroora   Startin             astartin16@webs.com  Female   612491
# 65  66      Deana    Gerran          dgerran1t@columbia.edu  Female  1201146
# 67  68   Lauretta   Creavin            lcreavin1v@patch.com  Female  1732422
#
#          state
# 22       Idaho
# 26    Illinois
# 42    New York
# 65  Washington
# 67       Texas

# %% [markdown]
# 20. Find the highest salary of all people from District of Columbia.

# %%
Columbia = df[df["state"]=="District of Columbia"]

max_sal_col = Columbia["salary"].max()

max_sal_col
# Out:
# np.int64(1997136)

# %% [markdown]
# 21. Select all females from New York with salaries between 500K and 1M.

# %%
New_fem = df[(df["state"]=="New York") & (df["salary"]>500000) & (df['salary']<1000000)]

New_fem.head()
# Out:
#       id  first_name last_name                     email  gender  salary  \
# 42    43     Auroora   Startin       astartin16@webs.com  Female  612491
# 44    45     Gustave  Ratcliff  gratcliff18@addtoany.com    Male  950972
# 81    82  Anna-diana      Lean        alean29@oracle.com  Female  846840
# 109  110     Cassius   D'Elias     cdelias31@jiathis.com    Male  900850
# 173  174        Erma    Grimes      egrimes4t@senate.gov  Female  727051
#
#         state
# 42   New York
# 44   New York
# 81   New York
# 109  New York
# 173  New York

# %% [markdown]
# 22. Count the number of people from Texas who have yahoo.com in their email.

# %%
Texas = df[df['state']=='Texas']

texas_yahoo = Texas[Texas['email'].str.contains("yahoo.com")]

count_texas_people = texas_yahoo['id'].count()

count_texas_people
# Out:
# np.int64(1)

# %% [markdown]
# 23. List all people whose salary is below the average salary for males in California.

# %%
California = df[df['state']=='California']

avg_cali = California['salary'].mean()

below_avg = df[df['salary']<avg_cali]

below_avg.head()
# Out:
#    id first_name  last_name                    email  gender  salary  \
# 0   1      Armin    Coltart     acoltart0@abc.net.au    Male  368693
# 1   2        Mia  Tuddenham  mtuddenham1@addthis.com  Female  154398
# 5   6      Denis     Martyn         dmartyn5@unc.edu    Male  547205
# 6   7     Waylin    Dorling       wdorling6@yelp.com    Male  790635
# 7   8       Jone     Pegden  jpegden7@washington.edu    Male  327962
#
#                   state
# 0  District of Columbia
# 1               Florida
# 5           Connecticut
# 6              Oklahoma
# 7            California
